# %%
import matplotlib.pyplot as plt
# %matplotlib inline
plt.rcParams['figure.figsize'] = 8,4
import pandas as pd
import numpy as np
import seaborn as sns

# %%
pokemon = pd.read_csv("C:\\Users\\Aparajith guha\\Desktop\\python\\pokemon.csv")

# %%
pokemon.tail()
# Out:
#      Number       Name   Type_1  Type_2   HP  Attack  Defense  Sp_Atk  Sp_Def  \
# 716     717    Yveltal     Dark  Flying  126     131       95     131      98
# 717     718    Zygarde   Dragon  Ground  108     100      121      81      95
# 718     719    Diancie     Rock   Fairy   50     100      150     100     150
# 719     720      Hoopa  Psychic   Ghost   80     110       60     150     130
# 720     721  Volcanion     Fire   Water   80     110      120     130      90
#
#      Speed  Generation   Color   Egg_Group_1 Egg_Group_2  Height_m  Weight_kg
# 716     99           6     Red  Undiscovered         NaN      5.79      203.0
# 717     95           6   Green  Undiscovered         NaN      5.00      305.0
# 718     50           6    Pink  Undiscovered         NaN      0.71        8.8
# 719     70           6  Purple  Undiscovered         NaN      0.51        9.0
# 720     70           6   Brown  Undiscovered         NaN      1.70      195.0

# %%
pokemon.columns
# Out:
# Index(['Number', 'Name', 'Type_1', 'Type_2', 'HP', 'Attack', 'Defense',
#        'Sp_Atk', 'Sp_Def', 'Speed', 'Generation', 'Color', 'Egg_Group_1',
#        'Egg_Group_2', 'Height_m', 'Weight_kg'],
#       dtype='object')

# %%
pokemon.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 721 entries, 0 to 720
# Data columns (total 23 columns):
# Number              721 non-null int64
# Name                721 non-null object
# Type_1              721 non-null object
# Type_2              350 non-null object
# Total               721 non-null int64
# HP                  721 non-null int64
# Attack              721 non-null int64
# Defense             721 non-null int64
# Sp_Atk              721 non-null int64
# Sp_Def              721 non-null int64
# Speed               721 non-null int64
# Generation          721 non-null int64
# isLegendary         721 non-null bool
# Color               721 non-null object
# hasGender           721 non-null bool
# Pr_Male             644 non-null float64
# Egg_Group_1         721 non-null object
# Egg_Group_2         191 non-null object
# hasMegaEvolution    721 non-null bool
# Height_m            721 non-null float64
# Weight_kg           721 non-null float64
# Catch_Rate          721 non-null int64
# Body_Style          721 non-null object
# dtypes: bool(3), float64(3), int64(10), object(7)
# memory usage: 114.8+ KB

# %%
pokemon.Name = pokemon.Name.astype('category')
pokemon.Type_1 = pokemon.Type_1.astype('category')
pokemon.Type_2 = pokemon.Type_2.astype('category')
pokemon.Color = pokemon.Color.astype('category')
pokemon.Egg_Group_1 = pokemon.Egg_Group_1.astype('category')
pokemon.Egg_Group_2 = pokemon.Egg_Group_2.astype('category')
pokemon.Body_Style = pokemon.Body_Style.astype('category')

# %%
k1 = sns.lmplot(data = pokemon, x = 'HP', y = 'Attack', hue = 'Egg_Group_1', fit_reg = False )
k2 = sns.lmplot(data = pokemon ,x = 'HP', y = 'Attack', hue = 'Egg_Group_2', fit_reg = False)

# %%
f, axes = plt.subplots(1,2, figsize = (12,6))
v1 = sns.violinplot(data = pokemon, y = 'Type_1' , x = 'Attack', width = 1,gridsize = 200 , ax = axes[0] )
v2 = sns.violinplot(data = pokemon, y = 'Type_2' , x = 'Attack', width = 1,gridsize = 100, ax = axes[1])

# %%
pokemon.columns
# Out:
# Index(['Number', 'Name', 'Type_1', 'Type_2', 'Total', 'HP', 'Attack',
#        'Defense', 'Sp_Atk', 'Sp_Def', 'Speed', 'Generation', 'isLegendary',
#        'Color', 'hasGender', 'Pr_Male', 'Egg_Group_1', 'Egg_Group_2',
#        'hasMegaEvolution', 'Height_m', 'Weight_kg', 'Catch_Rate',
#        'Body_Style'],
#       dtype='object')

# %%
data1 = np.array(pokemon[['Attack','Defense']])
plt.plot(data1)
# Out:
# [<matplotlib.lines.Line2D at 0x1feba24c358>,
#  <matplotlib.lines.Line2D at 0x1feba0ad6d8>]

# %%
sns.lvplot(data = pokemon[pokemon.Type_1 =='Bug'], x = 'Defense', y = 'Speed')

# %%
plt.scatter(data = pokemon, x = 'Speed', y = 'Attack',edgecolor = 'black')

# %%
f, axes = plt.subplots(1,2, figsize = (10,10))
v4 = sns.boxplot(data = pokemon, y = 'Type_1', x = 'Sp_Atk', ax = axes[0])
v5 = sns.boxplot(data = pokemon, y = 'Type_1', x = 'Sp_Def', ax = axes[1])

# %%
a = pokemon.dropna()

# %%
#Top 10 MAX HP pokemons
topHP = pokemon.sort_values(by = 'HP',ascending=False).head(10)
topHP
# Out:
#      Number       Name    Type_1   HP  Attack  Defense  Sp_Atk  Sp_Def  Speed  \
# 241     242    Blissey    Normal  255      10       10      75     135     55
# 112     113    Chansey    Normal  250       5        5      35     105     50
# 201     202  Wobbuffet   Psychic  190      33       58      33      58     33
# 320     321    Wailord     Water  170      90       45      90      45     60
# 593     594  Alomomola     Water  165      75       80      40      45     65
# 142     143    Snorlax    Normal  160     110       65      65     110     30
# 288     289    Slaking    Normal  150     160      100      95      65    100
# 486     487   Giratina     Ghost  150     120      100     120     100     90
# 425     426   Drifblim     Ghost  150      80       44      90      54     80
# 296     297   Hariyama  Fighting  144     120       60      40      60     50
#
#      Generation   Color   Egg_Group_1 Egg_Group_2  Height_m  Weight_kg
# 241           2    Pink         Fairy         NaN      1.50       46.8
# 112           1    Pink         Fairy         NaN      1.09       34.6
# 201           2    Blue     Amorphous         NaN      1.30       28.5
# 320           3    Blue         Field     Water_2     14.50      398.0
# 593           5    Pink       Water_1     Water_2      1.19       31.6
# 142           1   Black       Monster         NaN      2.11      460.0
# 288           3   Brown         Field         NaN      2.01      130.5
# 486           4   Black  Undiscovered         NaN      6.91      650.0
# 425           4  Purple     Amorphous         NaN      1.19       15.0
# 296           3   Brown    Human-Like         NaN      2.31      253.8

# %%
#Top 10 MAX Attack
topAttack = pokemon.sort_values(by = 'Attack',ascending=False).head(10)
topAttack
# Out:
#      Number        Name    Type_1   HP  Attack  Defense  Sp_Atk  Sp_Def  \
# 408     409   Rampardos      Rock   97     165       60      65      50
# 288     289     Slaking    Normal  150     160      100      95      65
# 485     486   Regigigas    Normal  110     160      110      80     110
# 643     644      Zekrom    Dragon  100     150      120     120     100
# 382     383     Groudon    Ground  100     150      140     100      90
# 383     384    Rayquaza    Dragon  105     150       90     150      90
# 385     386      Deoxys   Psychic   50     150       50     150      50
# 611     612     Haxorus    Dragon   76     147       90      60      70
# 566     567    Archeops      Rock   75     140       65     112      65
# 533     534  Conkeldurr  Fighting  105     140       95      55      65
#
#      Speed  Generation   Color   Egg_Group_1 Egg_Group_2  Height_m  Weight_kg
# 408     58           4    Blue       Monster         NaN      1.60      102.5
# 288    100           3   Brown         Field         NaN      2.01      130.5
# 485    100           4   White  Undiscovered         NaN      3.71      420.0
# 643     90           5   Black  Undiscovered         NaN      2.90      345.0
# 382     90           3     Red  Undiscovered         NaN      3.51      950.0
# 383     95           3   Green  Undiscovered         NaN      7.01      206.5
# 385    150           3     Red  Undiscovered         NaN      1.70       60.8
# 611     97           5  Yellow       Monster      Dragon      1.80      105.5
# 566    110           5  Yellow        Flying     Water_3      1.40       32.0
# 533     45           5    Grey    Human-Like         NaN      1.40       87.0

# %%
#Top 10 MAX Defense
topDefense = pokemon.sort_values(by = 'Defense',ascending=False).head(10)
topDefense
# Out:
#      Number       Name Type_1  HP  Attack  Defense  Sp_Atk  Sp_Def  Speed  \
# 212     213    Shuckle    Bug  20      10      230      10     230      5
# 207     208    Steelix  Steel  75      85      200      55      65     30
# 376     377   Regirock   Rock  80     100      200      50     100     50
# 712     713    Avalugg    Ice  95     117      184      44      46     28
# 305     306     Aggron  Steel  70     110      180      60      60     50
# 90       91   Cloyster  Water  50      95      180      85      45     70
# 410     411  Bastiodon   Rock  60      52      168      47     138     30
# 94       95       Onix   Rock  35      45      160      30      45     70
# 679     680   Doublade  Steel  59     110      150      45      49     35
# 718     719    Diancie   Rock  50     100      150     100     150     50
#
#      Generation   Color   Egg_Group_1 Egg_Group_2  Height_m  Weight_kg
# 212           2  Yellow           Bug         NaN      0.61       20.5
# 207           2    Grey       Mineral         NaN      9.19      400.0
# 376           3   Brown  Undiscovered         NaN      1.70      230.0
# 712           6    Blue       Monster         NaN      2.01      505.0
# 305           3    Grey       Monster         NaN      2.11      360.0
# 90            1  Purple       Water_3         NaN      1.50      132.5
# 410           4    Grey       Monster         NaN      1.30      149.5
# 94            1    Grey       Mineral         NaN      8.79      210.0
# 679           6   Brown       Mineral         NaN      0.84        4.5
# 718           6    Pink  Undiscovered         NaN      0.71        8.8

# %%
pokemon[pokemon.Name == 'Charizard']
# Out:
#    Number       Name Type_1  HP  Attack  Defense  Sp_Atk  Sp_Def  Speed  \
# 5       6  Charizard   Fire  78      84       78     109      85    100
#
#    Generation Color Egg_Group_1 Egg_Group_2  Height_m  Weight_kg
# 5           1   Red     Monster      Dragon       1.7       90.5

# %%
pokemon[pokemon.Name == 'Blastoise']
# Out:
#    Number       Name Type_1  HP  Attack  Defense  Sp_Atk  Sp_Def  Speed  \
# 8       9  Blastoise  Water  79      83      100      85     105     78
#
#    Generation Color Egg_Group_1 Egg_Group_2  Height_m  Weight_kg
# 8           1  Blue     Monster     Water_1       1.6       85.5

# %%
pokeMatrix = pokemon.as_matrix()

# %%
pokeMatrix[0]
# Out:
# array([1, 'Bulbasaur', 'Grass', 'Poison', 45, 49, 49, 65, 65, 45, 1,
#        'Green', 'Monster', 'Grass', 0.71, 6.9], dtype=object)

# %%
pokemon.columns
# Out:
# Index(['Number', 'Name', 'Type_1', 'HP', 'Attack', 'Defense', 'Sp_Atk',
#        'Sp_Def', 'Speed', 'Generation', 'Color', 'Egg_Group_1', 'Egg_Group_2',
#        'Height_m', 'Weight_kg'],
#       dtype='object')

# %%
del pokemon['Type_2']

# %%
pokeName = pokemon['Name'].as_matrix()

# %%
pokeType = pokemon['Type_1'].as_matrix()
pokeHP = pokemon['HP'].as_matrix()
pokeAttack = pokemon['Attack'].as_matrix(
pokeDefense = pokemon['Defense'].as_matrix()
pokeSpatk = pokemon['Sp_Atk'].as_matrix()
pokeSpdef = pokemon['Sp_Def'].as_matrix()
pokeSpeed = pokemon['Speed'].as_matrix()
pokeGen = pokemon['Generation'].as_matrix()
pokeColor = pokemon['Color'].as_matrix()
pokeEgg1 = pokemon['Egg_Group_1'].as_matrix()
pokeEgg2 = pokemon['Egg_Group_2'].as_matrix()
pokeHt = pokemon['Height_m'].as_matrix()
pokeWt = pokemon['Weight_kg'].as_matrix()

# %%
plt.plot(pokeAttack[5] ,c = 'Red', ls ='--', marker ='s',ms=7,label=pokeName[5])
plt.plot(pokeAttack[8] ,c = 'Blue', ls ='--', marker ='s',ms=7,label=pokeName[8])
plt.legend(loc='upper left',bbox_to_anchor=(1,1))

# %%
plt.plot(pokeHP[5] ,c = 'Red', ls ='--', marker ='s',ms=7,label=pokeName[5])
plt.plot(pokeHP[8] ,c = 'Blue', ls ='--', marker ='s',ms=7,label=pokeName[8])

# %%
plt.plot(pokeDefense[5] ,c = 'Red', ls ='--', marker ='s',ms=7,label=pokeName[5])
plt.plot(pokeDefense[8] ,c = 'Blue', ls ='--', marker ='s',ms=7,label=pokeName[8])

# %%
plt.scatter(pokeDefense, pokeAttack)

# %%
plt.hist(pokeDefense)
# Out:
# (array([  13.,  148.,  272.,  148.,   87.,   33.,   13.,    4.,    2.,    1.]),
#  array([   5. ,   27.5,   50. ,   72.5,   95. ,  117.5,  140. ,  162.5,
#          185. ,  207.5,  230. ]),
#  <a list of 10 Patch objects>)
